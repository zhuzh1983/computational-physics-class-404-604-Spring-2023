# %% [markdown]
# # Homework Lecture 9

# %% [markdown]
# 1. Solve the diffusion equation u_t=D u_{xx} with D=1 in the interval x=[0,1] from t=0 to t=0.1.
# 2. The initial condition is u(x,0)=0.5*(cos(13x)+1), the boundary condition is u(0,t)=1 and u(1,t)=0.
# 3. After solving the equation, please also change tend to a large value to see how the solution behave

# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as tck
import matplotlib.pylab as p
from mpl_toolkits.mplot3d import Axes3D 

import time
import math

# %%
"""Note: If we decrease the space step Δx without a simultaneous quadratic increase in the time step,
we will worsen the stability."""

Nx = 101 # number of points + boundary
Dt = 0.00001 # delta t (spacing)
tend = 1.
div = 2000

# Nx, Dt, final time, divisor over Nt (which controls the amount of lines in the graph, equally spaced in time)
def FTCS(Nx, Dt, tend, div):

    D=1.
    Nt = tend/Dt # total time steps - going from time t=0 to t=0.1
    div = 2000 # divisor for my graph number
    
    
    Dx = 1./(Nx-1); # delta x spacing; from 0 to 1 in Nx-1 spaces                                                 
    
    print("Δt = {:.2E}".format(Dt))
    print("Δx = {:.2E}".format(Dx))
    print("Nt = {:.2E}".format(Nt))
    
    # Stability condition
    if Dt < 0.5*(Dx**2)/D:
        print("Stability guaranteed. You may continue good sir.")
    else:
        raise SystemExit("EEEEEEEEEEEEEEEEE!!!!!!!")
    
    
    U = np.zeros([Nx,2]);
    
    U_pl = np.zeros([Nx,int(Nt/div)+1])
    
    xarr = np.zeros(Nx) # our point in the x-space grid
    
    # Initial condition
    #mu = 0.5;
    #sigma = 0.05;
    for ix in range (0, Nx):  
        xarr[ix]=ix*Dx #i times delta x
        U[ix,0] = 0.5*(np.cos(13*xarr[ix])+1) # Initial U
        
        # Little experiment
        #U[ix,0] = np.exp(-(xarr[ix]-mu)**2/(2*sigma**2))/np.sqrt(2*np.pi*sigma**2) # Initial U
        
        
    # Boundary conditions
    U[0,0] = 1. #for hw it's 1, for gaussian it's 0
    U[0,1] = 1.
    U[Nx-1,0] = 0.
    U[Nx-1,1] = 0.
    
    #Little experiment
    #U[0,0] = 0.
    #U[0,1] = 0.
    
    
    cons = D*Dt*Dx**-2 # constant
    m = 0 # counter selected plots to show
    toutn=0 # counter of iterations
    
    clr = ['xkcd:dark red','xkcd:red','xkcd:orange','xkcd:green','xkcd:blue','xkcd:indigo','xkcd:black']*100
    fig = plt.figure(figsize = (10,10))
    ax = fig.add_subplot(111)
    ax.set_ylim(-0.1,1.1)
    ax.set_xlim(0.,1.)
    ax.set_xlabel(r'$x$')
    ax.set_ylabel(r'$U(x,t)$')
    
    
    t=0.
    while t < tend:                                  
        for ix in range (1,Nx-1):            
            U[ix, 1] = U[ix, 0] +  cons*(U[ix+1, 0] + U[ix-1, 0] - 2.*U[ix,0])
            
        if toutn%2000 == 0: # Every 2000 steps
            for ix in range (1,Nx-1):
                U_pl[ix, m] = U[ix, 1]
            
            ax.plot(xarr, U[:,1],color=clr[m],linestyle='-',label=(r'$t={:.2f}$'.format(t)))
            ax.legend(loc='upper right')
            print("m = ",m)
            m = m + 1
            
        for ix in range (1, Nx - 1):
            U[ix, 0] = U[ix, 1]
        
        t+=Dt
        toutn+=1

# %%
Nx = 101 # number of points + boundary
Dt = 0.00001 # delta t (spacing)
tend = 0.1
div = 2000

FTCS(Nx, Dt, tend, div)
# Out:
# Δt = 1.00E-05
# Δx = 1.00E-02
# Nt = 1.00E+04
# Stability guaranteed. You may continue good sir.
# m =  0
# m =  1
# m =  2
# m =  3
# m =  4
# m =  5

# %%
Nx = 101 # number of points + boundary
Dt = 0.00001 # delta t (spacing)
tend = 10.
div = 2000

FTCS(Nx, Dt, tend, div)
# Out:
# Δt = 1.00E-05
# Δx = 1.00E-02
# Nt = 1.00E+06
# Stability guaranteed. You may continue good sir.
# m =  0
# m =  1
# m =  2
# m =  3
# m =  4
# m =  5
# m =  6
# m =  7
# m =  8
# m =  9
# m =  10
# m =  11
# m =  12
# m =  13
# m =  14
# m =  15
# m =  16
# m =  17
# m =  18
# m =  19
# m =  20
# m =  21
# m =  22
# m =  23
# m =  24
# m =  25
# m =  26
# m =  27
# m =  28
# m =  29
# m =  30
# m =  31
# m =  32
# m =  33
# m =  34
# m =  35
# m =  36
# m =  37
# m =  38
# m =  39
# m =  40
# m =  41
# m =  42
# m =  43
# m =  44
# m =  45
# m =  46
# m =  47
# m =  48
# m =  49
# m =  50
# m =  51
# m =  52
# m =  53
# m =  54
# m =  55
# m =  56
# m =  57
# m =  58
# m =  59
# m =  60
# m =  61
# m =  62
# m =  63
# m =  64
# m =  65
# m =  66
# m =  67
# m =  68
# m =  69
# m =  70
# m =  71
# m =  72
# m =  73
# m =  74
# m =  75
# m =  76
# m =  77
# m =  78
# m =  79
# m =  80
# m =  81
# m =  82
# m =  83
# m =  84
# m =  85
# m =  86
# m =  87
# m =  88
# m =  89
# m =  90
# m =  91
# m =  92
# m =  93
# m =  94
# m =  95
# m =  96
# m =  97
# m =  98
# m =  99
# m =  100
# m =  101
# m =  102
# m =  103
# m =  104
# m =  105
# m =  106
# m =  107
# m =  108
# m =  109
# m =  110
# m =  111
# m =  112
# m =  113
# m =  114
# m =  115
# m =  116
# m =  117
# m =  118
# m =  119
# m =  120
# m =  121
# m =  122
# m =  123
# m =  124
# m =  125
# m =  126
# m =  127
# m =  128
# m =  129
# m =  130
# m =  131
# m =  132
# m =  133
# m =  134
# m =  135
# m =  136
# m =  137
# m =  138
# m =  139
# m =  140
# m =  141
# m =  142
# m =  143
# m =  144
# m =  145
# m =  146
# m =  147
# m =  148
# m =  149
# m =  150
# m =  151
# m =  152
# m =  153
# m =  154
# m =  155
# m =  156
# m =  157
# m =  158
# m =  159
# m =  160
# m =  161
# m =  162
# m =  163
# m =  164
# m =  165
# m =  166
# m =  167
# m =  168
# m =  169
# m =  170
# m =  171
# m =  172
# m =  173
# m =  174
# m =  175
# m =  176
# m =  177
# m =  178
# m =  179
# m =  180
# m =  181
# m =  182
# m =  183
# m =  184
# m =  185
# m =  186
# m =  187
# m =  188
# m =  189
# m =  190
# m =  191
# m =  192
# m =  193
# m =  194
# m =  195
# m =  196
# m =  197
# m =  198
# m =  199
# m =  200
# m =  201
# m =  202
# m =  203
# m =  204
# m =  205
# m =  206
# m =  207
# m =  208
# m =  209
# m =  210
# m =  211
# m =  212
# m =  213
# m =  214
# m =  215
# m =  216
# m =  217
# m =  218
# m =  219
# m =  220
# m =  221
# m =  222
# m =  223
# m =  224
# m =  225
# m =  226
# m =  227
# m =  228
# m =  229
# m =  230
# m =  231
# m =  232
# m =  233
# m =  234
# m =  235
# m =  236
# m =  237
# m =  238
# m =  239
# m =  240
# m =  241
# m =  242
# m =  243
# m =  244
# m =  245
# m =  246
# m =  247
# m =  248
# m =  249
# m =  250
# m =  251
# m =  252
# m =  253
# m =  254
# m =  255
# m =  256
# m =  257
# m =  258
# m =  259
# m =  260
# m =  261
# m =  262
# m =  263
# m =  264
# m =  265
# m =  266
# m =  267
# m =  268
# m =  269
# m =  270
# m =  271
# m =  272
# m =  273
# m =  274
# m =  275
# m =  276
# m =  277
# m =  278
# m =  279
# m =  280
# m =  281
# m =  282
# m =  283
# m =  284
# m =  285
# m =  286
# m =  287
# m =  288
# m =  289
# m =  290
# m =  291
# m =  292
# m =  293
# m =  294
# m =  295
# m =  296
# m =  297
# m =  298
# m =  299
# m =  300
# m =  301
# m =  302
# m =  303
# m =  304
# m =  305
# m =  306
# m =  307
# m =  308
# m =  309
# m =  310
# m =  311
# m =  312
# m =  313
# m =  314
# m =  315
# m =  316
# m =  317
# m =  318
# m =  319
# m =  320
# m =  321
# m =  322
# m =  323
# m =  324
# m =  325
# m =  326
# m =  327
# m =  328
# m =  329
# m =  330
# m =  331
# m =  332
# m =  333
# m =  334
# m =  335
# m =  336
# m =  337
# m =  338
# m =  339
# m =  340
# m =  341
# m =  342
# m =  343
# m =  344
# m =  345
# m =  346
# m =  347
# m =  348
# m =  349
# m =  350
# m =  351
# m =  352
# m =  353
# m =  354
# m =  355
# m =  356
# m =  357
# m =  358
# m =  359
# m =  360
# m =  361
# m =  362
# m =  363
# m =  364
# m =  365
# m =  366
# m =  367
# m =  368
# m =  369
# m =  370
# m =  371
# m =  372
# m =  373
# m =  374
# m =  375
# m =  376
# m =  377
# m =  378
# m =  379
# m =  380
# m =  381
# m =  382
# m =  383
# m =  384
# m =  385
# m =  386
# m =  387
# m =  388
# m =  389
# m =  390
# m =  391
# m =  392
# m =  393
# m =  394
# m =  395
# m =  396
# m =  397
# m =  398
# m =  399
# m =  400
# m =  401
# m =  402
# m =  403
# m =  404
# m =  405
# m =  406
# m =  407
# m =  408
# m =  409
# m =  410
# m =  411
# m =  412
# m =  413
# m =  414
# m =  415
# m =  416
# m =  417
# m =  418
# m =  419
# m =  420
# m =  421
# m =  422
# m =  423
# m =  424
# m =  425
# m =  426
# m =  427
# m =  428
# m =  429
# m =  430
# m =  431
# m =  432
# m =  433
# m =  434
# m =  435
# m =  436
# m =  437
# m =  438
# m =  439
# m =  440
# m =  441
# m =  442
# m =  443
# m =  444
# m =  445
# m =  446
# m =  447
# m =  448
# m =  449
# m =  450
# m =  451
# m =  452
# m =  453
# m =  454
# m =  455
# m =  456
# m =  457
# m =  458
# m =  459
# m =  460
# m =  461
# m =  462
# m =  463
# m =  464
# m =  465
# m =  466
# m =  467
# m =  468
# m =  469
# m =  470
# m =  471
# m =  472
# m =  473
# m =  474
# m =  475
# m =  476
# m =  477
# m =  478
# m =  479
# m =  480
# m =  481
# m =  482
# m =  483
# m =  484
# m =  485
# m =  486
# m =  487
# m =  488
# m =  489
# m =  490
# m =  491
# m =  492
# m =  493
# m =  494
# m =  495
# m =  496
# m =  497
# m =  498
# m =  499
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-2069880b4230> in <module>
#       4 div = 2000
#       5
# ----> 6 FTCS(Nx, Dt, tend, div)
#
# <ipython-input-111-a16df53dc440> in FTCS(Nx, Dt, tend, div)
#      76         if toutn%2000 == 0 or t == 0.1: # Every 2000 steps
#      77             for ix in range (1,Nx-1):
# ---> 78                 U_pl[ix, m] = U[ix, 1]
#      79
#      80             ax.plot(xarr, U[:,1],color=clr[m],linestyle='-',label=(r'$t={:.2f}$'.format(t)))
#
# IndexError: index 500 is out of bounds for axis 1 with size 500

# %% [markdown]
# At $t = 0.1$, it appears the system moves towards a negative-slope-straight-line resting position; oscillations are still visible but subdued.
#
# At a much larger time $t >> 0.1$ it seems to me this conclusion still holds.
